# %% [markdown]
# <a href="https://colab.research.google.com/github/YasminGarcia1210/TAREAS/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Hola**
#
#
#
# #hola
#
# ##hola
#
# **hola**
#
# *hola*

# %% [markdown]
# |Bloque1|Bloque2|
# |-------|-------|
# |dljshi | dljsih|
# |iopj   |kjg    |

# %% [markdown]
# ![gato.jpg](data:image/jpeg;base64,...)
